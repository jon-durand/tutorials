# %%
# import pandas
import pandas as pd

# import matplotlib
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://pynative.com/wp-content/uploads/2019/01/company_sales_data.csv')

# %%
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %% [markdown]
# # Objective: Read Total profit of all months and show it using a line plot

# %%
from cycler import cycler
cyc = cycler(color = ['#377eb8', '#ff7f00', '#4daf4a',
                  '#f781bf', '#a65628', '#984ea3',
                  '#999999', '#e41a1c', '#dede00'])
ax.set_prop_cycle(cyc)

x= df.month_number.values
y= df.total_profit.values

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(x,y)
ax.set_title('Total Profits By Month')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')

plt.show()

# %% [markdown]
# # Objective: Read all product sales data and show it  using a multiline plot

# %%
df.columns
# Out:
# Index(['month_number', 'facecream', 'facewash', 'toothpaste', 'bathingsoap',
#        'shampoo', 'moisturizer', 'total_units', 'total_profit'],
#       dtype='object')

# %%
x= df.month_number.values
y1 = df.facecream.values
y2 = df.facewash.values
y3 = df.toothpaste.values
y4 = df.bathingsoap.values
y5 = df.shampoo.values
y6 = df.moisturizer.values

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(x,y1,label='facecream',linewidth=2)
ax.plot(x,y2,label='facewash',linewidth=2)
ax.plot(x,y3,label='toothpaste',linewidth=2)
ax.plot(x,y4,label='bathingsoap',linewidth=2)
ax.plot(x,y5,label='shampoo',linewidth=2)
ax.plot(x,y6,label='moisturizer',linewidth=2)

ax.set_title('Sales By Product')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')

plt.show()

# %% [markdown]
# # Objective: Read the total profit of each month and show it using the histogram to see most common profit ranges

# %%
# Histogram
fig, ax = plt.subplots(figsize=(10,6))
x= df.month_number.values
y= df.total_profit.values
ax.hist(y, histtype='bar', rwidth=0.8)
ax.set_title('Histogram')
ax.set_xlabel('month')
ax.set_ylabel('total_profits')
plt.show()

# %%
df.total_profit.values
# Out:
# array([211000, 183300, 224700, 222700, 209600, 201400, 295500, 361400,
#        234000, 266700, 412800, 300200])
